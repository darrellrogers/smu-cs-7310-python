# %% [markdown]
# ## CS 7310 Midterm Exam
# ### Be sure to name your notebook: midt.lastname.ipynb
# ### Submit your notebook AFTER it has been executed with output showing

# %% [markdown]
# ### Enter Name and ID:
# - Name:
# - ID:

# %% [markdown]
# ## 1	Comparing Speed of NumPy vs. Python Iteration
# - The NumPy library, written in C, is known for its speed. In this exercise you will compare the performance of the NumPy function sum() vs. a Python loop to sum all the values in a 2D NumPy array and report how many times faster (or slower) Numpy sum() is compared to Python iteration.

# %% [markdown]
# ## 1.1 Create a 1D numpy array of 100 million floating point numbers
# - Name the array <b>arr1d</b>

# %%
# CODE: create NumPy array called arr1d with 100 million floats

# %%
# ASSERT: Do not modify 
# Test that your array has 1 million floating point numbers

try: 
    assert arr1d.size == 100000000
    assert arr1d.dtype == 'float64'
    assert arr1d.sum() == 4999999950000000.0
    print ("Passed M1.1")
except:
    print ("Problem with your array. See assert values")

# %% [markdown]
# ### Convert the 1D array to 2D - this is a bit tricky so here is the code..

# %%
# Code Provided provided for you to convert 1D to 2D array
# DO NOT Modify
ncols = 100
arr2d = np.reshape(arr1d, (-1, ncols))
print (arr2d.shape)
try:
    assert arr2d.shape == (1000000,100)
    print ("Array looks good - proceed with the tests")
except:
    print ("Problem with array ??")

# %% [markdown]
# ## 1.1  Write a function that uses NumPy sum() and measure speed
# - Write a function compute_np_sum(arr) that returns the sum of arr2d using the numpy sum function
# - Use your Python timing technique to determine the speed of numpy sum()

# %%
# CODE:  write code for function and measure tim

def compute_np_sum(arr):
    pass

# %% [markdown]
# ## 1.2 Write a function that uses iteration to sum array one element at a time and measure speed
# - Write a function  compute_iter_sum(arr) that returns the sum of a 2D using iteration
# - Your function should work for ANY size NumPy 2D array
# - Use two loops to iterate over all the values in the rows and columns ONE ENTRY AT A TIME
# - return the sum and measure the time it takes

# %%
# CODE: write code for function and measure time for ANY size arr2d

def compute_iter_sum(arr):
    pass

# %% [markdown]
# ## Test that your compute_iter_sum code works for ANY 2D array

# %%
# ASSERT: DO not modify
# test that your compute_iter_sum code works for small 2D array
s = (2,2)
small_arr = np.ones(s, dtype=int)

try:
    assert compute_iter_sum(small_arr) == 4
    print ("OK. now move on to test that you have correct sum values")
except:
    print ("FAIL. You code does not work for a small 2D array")

# %%
# ASSERT: Test that values are correct - do not modify'

try:
    npsum = compute_np_sum(arr2d)
    itersum = compute_iter_sum(arr2d)

    assert npsum == itersum
    assert npsum == 4999999950000000.0
    print ("Passed M1.2")
except:
    print ("Fail: Your two functions should return the SAME value: 4999999950000000.0 Stop and redo")

# %% [markdown]
# ## 1.3 RESULTS
# - How many times faster (or slower) is the built in sum() function vs computing the sum with loops
# - Use matplotlib to display a bar chart that shows the 2 time values. If one value is significantly greater than the other, use the log display feature of matplotlib to get a better visualization of the difference.
# - Label the bar chart with a descriptive title and axis labels that will show a reader unfamilar with the assignment, what the graph represents
# - Modify the print statement to show the speed up as an integer value (do not hard code)

# %%
# Bar chart code and print speedup value



# insert your value below
print("NumPy sum  is ", 0, " times faster than item by item iteration")

# %% [markdown]
# # 2. Titanic CSV Data Set Processing
#
# - Load the Titanic CSV dataset into a pandas DataFrame. See the Midterm zipfile for titanic.csv
# - Determine the number of individuals who died vs. those that survived
# - Plot these values with a Bar Chart using pyplot
# - Use meaningful terms for the chart title and axes such that someone unfamiliar with the assignment will understand the bar chart
# - Modify the print statement and the end of the code block to show number died and number survived

# %%
# CODE: load Titanic data set. Create Bar graph and modify the print statements





print(f"Total number of individuals who survived:", 0)
print(f"Total number of individuals who Died:", 0)

# %% [markdown]
# # 2b. Survivor Age Graph
#
# - For all survivors, use pyplot to create a bar chart that shows the number of survivors in each age category using the following categories: 0-10, 11-20, 21-30, 31-40, 41-50, 51-60, 61-100
# - Create two variables survivors_0_10 and survivors_61_100 with values that come from your code.
# - Use these variables in the print statement after your bar chart

# %%
# Code Bar Grapoh here





print ("Survivors 0-10:", 0, "61-100:", 0)

# %% [markdown]
# ## 2c. Number of missing age values
# - the Titanic data set has several missing values for Age
# - write code to determine the number of missing Age values and store in variable missing_ages
# - use your value for missing_ages in the print statement

# %%
# Code to determine number of missing ages








print (f"Number missing ages:", 0 )

# %% [markdown]
# - ## Question 3
# Copy the code below and use a debugger (e.g. in Pycharm) to answer the following questions.
#
# - What is the value of the sum when idx = 99 but BEFORE sum gets incremented inside the loop?
# - WHat is the value of sum just AFTER the sum gets incremented in the same loop.
#
# - Use the debugger STEP function to step thru the loop, what is the value of sum AFTER sum gets incremented?
# - Complete the print statement at the end of the block

# %%
# Rollo's code:
def foo(n):
    sum = 0
    for idx in range(n):
        sum = sum + 0.01 * idx
    return sum

sum = foo(2000)


print ("The value BEFORE increment:", 0)  # use value obtained from debugger
print ("The value AFTER  increment:", 0)

# %% [markdown]
# ## Take screen shots of your work in the debugger and add to the zip file when you submit your assignment
